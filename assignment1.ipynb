# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
#import libraries 

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

# %%
df = pd.read_csv('/content/archive.zip')

# %%
#first five rows
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S
# 2               US            S
# 3               CA            M
# 4               CA            M

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
#checking for null values
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
#                      ..
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# Length: 11, dtype: int64

# %%
#for checking the unique values in a column
df['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
#replacing some values for better understanding
df['experience_level'] = df['experience_level'].replace('EN','Entry-level/Junior')
df['experience_level'] = df['experience_level'].replace('MI','Mid-level/Intermediate')
df['experience_level'] = df['experience_level'].replace('SE','Senior-level/Expert')
df['experience_level'] = df['experience_level'].replace('EX','Executive-level/Director')

df['employment_type'] = df['employment_type'].replace('FL','Freelancer')
df['employment_type'] = df['employment_type'].replace('CT','Contractor')
df['employment_type'] = df['employment_type'].replace('FT','Full-Time')
df['employment_type'] = df['employment_type'].replace('PT','Part-Time')


df['company_size'] = df['company_size'].replace('S','Small')
df['company_size'] = df['company_size'].replace('M','Medium')
df['company_size'] = df['company_size'].replace('L','Large')

# %%
#rename columns
df.rename(columns={'salary_in_usd':'Salary(USD)'},inplace = True)
df.rename(columns={'work_year':'Year'},inplace=True)
#drop unnecessary column
df.drop(['salary'], axis=1,inplace = True)
df.drop(['salary_currency'], axis=1,inplace = True)
df.drop(['remote_ratio'], axis=1,inplace = True)
df.drop(['employee_residence'], axis=1,inplace = True)

# %%
#final dataframe
df.head()
# Out:
#    Year        experience_level employment_type                 job_title  \
# 0  2023     Senior-level/Expert       Full-Time  Principal Data Scientist
# 1  2023  Mid-level/Intermediate      Contractor               ML Engineer
# 2  2023  Mid-level/Intermediate      Contractor               ML Engineer
# 3  2023     Senior-level/Expert       Full-Time            Data Scientist
# 4  2023     Senior-level/Expert       Full-Time            Data Scientist
#
#    Salary(USD) company_location company_size
# 0        85847               ES        Large
# 1        30000               US        Small
# 2        25500               US        Small
# 3       175000               CA       Medium
# 4       120000               CA       Medium

# %%
top_10=df['job_title'].value_counts()[:10].rename_axis('job_title').reset_index(name='count')
top_10.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fdbb8_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fdbb8_row1_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_fdbb8_row2_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_fdbb8_row3_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_fdbb8_row4_col1, #T_fdbb8_row5_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_fdbb8_row6_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_fdbb8_row7_col1, #T_fdbb8_row8_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_fdbb8_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fdbb8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdbb8_level0_col0" class="col_heading level0 col0" >job_title</th>
#       <th id="T_fdbb8_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdbb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdbb8_row0_col0" class="data row0 col0" >Data Engineer</td>
#       <td id="T_fdbb8_row0_col1" class="data row0 col1" >1040</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdbb8_row1_col0" class="data row1 col0" >Data Scientist</td>
#       <td id="T_fdbb8_row1_col1" class="data row1 col1" >840</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdbb8_row2_col0" class="data row2 col0" >Data Analyst</td>
#       <td id="T_fdbb8_row2_col1" class="data row2 col1" >612</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fdbb8_row3_col0" class="data row3 col0" >Machine Learning Engineer</td>
#       <td id="T_fdbb8_row3_col1" class="data row3 col1" >289</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fdbb8_row4_col0" class="data row4 col0" >Analytics Engineer</td>
#       <td id="T_fdbb8_row4_col1" class="data row4 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fdbb8_row5_col0" class="data row5 col0" >Data Architect</td>
#       <td id="T_fdbb8_row5_col1" class="data row5 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fdbb8_row6_col0" class="data row6 col0" >Research Scientist</td>
#       <td id="T_fdbb8_row6_col1" class="data row6 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fdbb8_row7_col0" class="data row7 col0" >Data Science Manager</td>
#       <td id="T_fdbb8_row7_col1" class="data row7 col1" >58</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fdbb8_row8_col0" class="data row8 col0" >Applied Scientist</td>
#       <td id="T_fdbb8_row8_col1" class="data row8 col1" >58</td>
#     </tr>
#     <tr>
#       <th id="T_fdbb8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fdbb8_row9_col0" class="data row9 col0" >Research Engineer</td>
#       <td id="T_fdbb8_row9_col1" class="data row9 col1" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(20,4))   #Set the width and height of the figure
plt.title("Top 10 jobs in 2023")     #Add title
# Out:
# Text(0.5, 1.0, 'Top 10 jobs in 2023')

# %%
#average salaries and company size
avg_salaries_based_oncompanysize=np.array(df['Salary(USD)'].groupby(df['company_size']).mean())
avg_salaries_based_oncompanysize
# Out:
# array([118300.98237885, 143130.54836663,  78226.68243243])

# %%
#average salaries and year
avg_salaries_based_onyear=np.array(df['Salary(USD)'].groupby(df['Year']).mean())
avg_salaries_based_onyear
# Out:
# array([ 92302.63157895,  94087.20869565, 133338.62079327, 149045.54117647])

# %%
plt.title('Average Salaries based on Year')
plt.xlabel('Year')
plt.ylabel('Salary(USD)')
sns.set_style("darkgrid")    # to  change the style of the figure to the "dark" theme

sns.lineplot(x=['2020', '2021', '2022','2023'],y=avg_salaries_based_onyear)
# Out:
# <Axes: title={'center': 'Average Salaries based on Year'}, xlabel='Year', ylabel='Salary(USD)'>

# %%
#to find the total count of unique elements in the experience level column
df['experience_level'].value_counts()
# Out:
# Senior-level/Expert         2516
# Mid-level/Intermediate       805
# Entry-level/Junior           320
# Executive-level/Director     114
# Name: experience_level, dtype: int64

# %%
# to create a table with selected features for better understanding
df.groupby(['experience_level','Year','job_title']).mean().style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c9ecd_row0_col0, #T_c9ecd_row110_col0, #T_c9ecd_row124_col0, #T_c9ecd_row203_col0 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_c9ecd_row1_col0, #T_c9ecd_row59_col0, #T_c9ecd_row81_col0, #T_c9ecd_row113_col0, #T_c9ecd_row200_col0 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_c9ecd_row2_col0, #T_c9ecd_row49_col0, #T_c9ecd_row56_col0, #T_c9ecd_row71_col0, #T_c9ecd_row155_col0, #T_c9ecd_row184_col0, #T_c9ecd_row227_col0, #T_c9ecd_row265_col0, #T_c9ecd_row310_col0 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_c9ecd_row3_col0, #T_c9ecd_row31_col0, #T_c9ecd_row133_col0, #T_c9ecd_row181_col0, #T_c9ecd_row244_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_c9ecd_row4_col0, #T_c9ecd_row35_col0, #T_c9ecd_row67_col0, #T_c9ecd_row121_col0 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_c9ecd_row5_col0, #T_c9ecd_row27_col0, #T_c9ecd_row62_col0, #T_c9ecd_row120_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c9ecd_row6_col0, #T_c9ecd_row122_col0, #T_c9ecd_row139_col0, #T_c9ecd_row172_col0, #T_c9ecd_row226_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_c9ecd_row7_col0, #T_c9ecd_row24_col0, #T_c9ecd_row43_col0, #T_c9ecd_row66_col0, #T_c9ecd_row188_col0, #T_c9ecd_row211_col0 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_c9ecd_row8_col0, #T_c9ecd_row210_col0 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_c9ecd_row9_col0, #T_c9ecd_row17_col0, #T_c9ecd_row34_col0, #T_c9ecd_row36_col0, #T_c9ecd_row60_col0, #T_c9ecd_row204_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_c9ecd_row10_col0, #T_c9ecd_row50_col0, #T_c9ecd_row137_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_c9ecd_row11_col0, #T_c9ecd_row118_col0, #T_c9ecd_row266_col0 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_c9ecd_row12_col0, #T_c9ecd_row130_col0, #T_c9ecd_row136_col0 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_c9ecd_row13_col0, #T_c9ecd_row37_col0, #T_c9ecd_row166_col0 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_c9ecd_row14_col0, #T_c9ecd_row140_col0 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_c9ecd_row15_col0, #T_c9ecd_row21_col0, #T_c9ecd_row284_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_c9ecd_row16_col0 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_c9ecd_row18_col0, #T_c9ecd_row22_col0, #T_c9ecd_row115_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_c9ecd_row19_col0, #T_c9ecd_row149_col0, #T_c9ecd_row164_col0, #T_c9ecd_row318_col0, #T_c9ecd_row323_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_c9ecd_row20_col0, #T_c9ecd_row170_col0, #T_c9ecd_row290_col0 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_c9ecd_row23_col0, #T_c9ecd_row63_col0, #T_c9ecd_row158_col0, #T_c9ecd_row202_col0, #T_c9ecd_row216_col0, #T_c9ecd_row277_col0 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_c9ecd_row25_col0, #T_c9ecd_row317_col0 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_c9ecd_row26_col0, #T_c9ecd_row39_col0, #T_c9ecd_row163_col0, #T_c9ecd_row195_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_c9ecd_row28_col0, #T_c9ecd_row205_col0, #T_c9ecd_row274_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_c9ecd_row29_col0, #T_c9ecd_row38_col0, #T_c9ecd_row41_col0, #T_c9ecd_row42_col0, #T_c9ecd_row117_col0, #T_c9ecd_row183_col0, #T_c9ecd_row185_col0, #T_c9ecd_row343_col0, #T_c9ecd_row350_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_c9ecd_row30_col0, #T_c9ecd_row74_col0 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_c9ecd_row32_col0, #T_c9ecd_row70_col0 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_c9ecd_row33_col0, #T_c9ecd_row64_col0, #T_c9ecd_row65_col0, #T_c9ecd_row75_col0, #T_c9ecd_row169_col0, #T_c9ecd_row201_col0, #T_c9ecd_row206_col0, #T_c9ecd_row263_col0, #T_c9ecd_row313_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_c9ecd_row40_col0, #T_c9ecd_row80_col0, #T_c9ecd_row134_col0, #T_c9ecd_row141_col0, #T_c9ecd_row162_col0, #T_c9ecd_row285_col0 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_c9ecd_row44_col0, #T_c9ecd_row246_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_c9ecd_row45_col0, #T_c9ecd_row167_col0, #T_c9ecd_row240_col0 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_c9ecd_row46_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_c9ecd_row47_col0, #T_c9ecd_row132_col0, #T_c9ecd_row336_col0 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_c9ecd_row48_col0, #T_c9ecd_row151_col0, #T_c9ecd_row186_col0, #T_c9ecd_row198_col0, #T_c9ecd_row254_col0 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_c9ecd_row51_col0, #T_c9ecd_row52_col0, #T_c9ecd_row84_col0, #T_c9ecd_row99_col0, #T_c9ecd_row304_col0 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_c9ecd_row53_col0, #T_c9ecd_row232_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_c9ecd_row54_col0, #T_c9ecd_row126_col0 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_c9ecd_row55_col0, #T_c9ecd_row255_col0, #T_c9ecd_row301_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_c9ecd_row57_col0, #T_c9ecd_row58_col0, #T_c9ecd_row88_col0, #T_c9ecd_row191_col0, #T_c9ecd_row328_col0, #T_c9ecd_row332_col0 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_c9ecd_row61_col0, #T_c9ecd_row102_col0, #T_c9ecd_row239_col0, #T_c9ecd_row292_col0, #T_c9ecd_row335_col0 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_c9ecd_row68_col0 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_c9ecd_row69_col0, #T_c9ecd_row125_col0, #T_c9ecd_row253_col0, #T_c9ecd_row273_col0, #T_c9ecd_row307_col0 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_c9ecd_row72_col0, #T_c9ecd_row77_col0, #T_c9ecd_row157_col0, #T_c9ecd_row194_col0 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_c9ecd_row73_col0, #T_c9ecd_row153_col0, #T_c9ecd_row207_col0 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_c9ecd_row76_col0, #T_c9ecd_row236_col0 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_c9ecd_row78_col0 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_c9ecd_row79_col0 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_c9ecd_row82_col0, #T_c9ecd_row242_col0, #T_c9ecd_row250_col0, #T_c9ecd_row306_col0, #T_c9ecd_row348_col0 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_c9ecd_row83_col0 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_c9ecd_row85_col0 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_c9ecd_row86_col0, #T_c9ecd_row262_col0, #T_c9ecd_row286_col0, #T_c9ecd_row297_col0, #T_c9ecd_row333_col0, #T_c9ecd_row340_col0 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_c9ecd_row87_col0, #T_c9ecd_row294_col0 {
#   background-color: #a2d99c;
#   color: #000000;
# }
# #T_c9ecd_row89_col0 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_c9ecd_row90_col0, #T_c9ecd_row233_col0, #T_c9ecd_row319_col0, #T_c9ecd_row338_col0 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_c9ecd_row91_col0, #T_c9ecd_row104_col0, #T_c9ecd_row208_col0, #T_c9ecd_row261_col0 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_c9ecd_row92_col0 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_c9ecd_row93_col0, #T_c9ecd_row251_col0 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_c9ecd_row94_col0, #T_c9ecd_row192_col0 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_c9ecd_row95_col0, #T_c9ecd_row247_col0, #T_c9ecd_row279_col0, #T_c9ecd_row309_col0, #T_c9ecd_row344_col0 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_c9ecd_row96_col0, #T_c9ecd_row129_col0, #T_c9ecd_row165_col0, #T_c9ecd_row176_col0, #T_c9ecd_row214_col0, #T_c9ecd_row339_col0 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_c9ecd_row97_col0, #T_c9ecd_row109_col0, #T_c9ecd_row116_col0, #T_c9ecd_row156_col0, #T_c9ecd_row171_col0 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_c9ecd_row98_col0, #T_c9ecd_row218_col0, #T_c9ecd_row221_col0, #T_c9ecd_row300_col0 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_c9ecd_row100_col0, #T_c9ecd_row30

# %%
#heatmap of confusion matrix
plt.title('Confusion Matrix')
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: title={'center': 'Confusion Matrix'}>

# %%
m=df['Salary(USD)'].mean()
print('Average Salary: ',round(m,0),"(USD)")
# Out:
# Average Salary:  137570.0 (USD)
